# %%
#transporting necessary package

import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("unconditional probablity.csv")

# %%
print(df.head(10))
# Out:
#                 Song Name   P(S)=X1  P(r )=X2   P(R)=X3   P(g)=X4  P(G)=X5  \
# 0              Raag Bahar  0.313253         0  0.060241  0.096386    0.000
# 1               Raag Pilu  0.125000         0  0.100000  0.162500    0.125
# 2            Raag Patdeep  0.171429         0  0.042857  0.114286    0.000
# 3         Raag Bhimpalasi  0.211268         0  0.098592  0.126761    0.000
# 4           Raag Bageshri  0.313953         0  0.104651  0.081395    0.000
# 5               Raag Kafi  0.166667         0  0.090909  0.181818    0.000
# 6  Raag Brindabani Sarang  0.023529         0  0.152941  0.000000    0.000
#
#     P(M)=X6  P(m)=X7   P(P)=X8  P(d)=X9  P(D)=X10  P(n)=X11  P(N)=X12
# 0  0.132530        0  0.072289        0  0.060241  0.120482  0.144578
# 1  0.200000        0  0.137500        0  0.025000  0.000000  0.125000
# 2  0.085714        0  0.228571        0  0.114286  0.000000  0.242857
# 3  0.183099        0  0.211268        0  0.028169  0.140845  0.000000
# ...

# %%
x=pd.plotting.andrews_curves(df,'Song Name')
